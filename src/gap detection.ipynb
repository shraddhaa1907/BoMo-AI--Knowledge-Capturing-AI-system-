# %%
import whisper
model=whisper.load_model("base")
result=model.transcribe("audio/sample_audio.mp3")
print(result[text])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import whisper
#       2 model=whisper.load_model("base")
#       3 result=model.transcribe("audio/sample_audio.mp3")
#
# ModuleNotFoundError: No module named 'whisper'
